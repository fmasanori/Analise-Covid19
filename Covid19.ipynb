# %% [markdown]
# ### Disclaimer/Aviso Legal: Este notebook tem um fim única e exclusivamente didático, para alunos da FATEC, como uma introdução à Análise de Dados Públicos. Desse modo, está excluída a garantia ou responsabilidade de qualquer tipo, por exemplo, de precisão, confiabilidade, completude e atualidade das informações

# %% [markdown]
# #### O presente arquivo é do dia 01/07/2020. Atenção: A semana 27 está incompleta!

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import geopandas as gpd
plt.style.use('classic')
# %matplotlib inline

# %%
filename = r'HIST_PAINEL_COVIDBR_01jul2020.xlsx'
df = pd.read_excel(filename)

# %%
sp = gpd.read_file('C:/GeoPandas/sp_municipios/SP_Municipios_2019.shp')

# %%
df.sample(10)
# Out:
#               regiao estado           municipio  coduf    codmun  \
# 219567       Sudeste     MG            Alterosa     31  310200.0
# 144272      Nordeste     PE           Araçoiaba     26  260105.0
# 22009          Norte     PA              Chaves     15  150250.0
# 516004  Centro-Oeste     GO         Novo Brasil     52  521520.0
# 500079  Centro-Oeste     MT  Serra Nova Dourada     51  510788.0
# 325655       Sudeste     SP              Brotas     35  350790.0
# 396390           Sul     PR   Marilândia do Sul     41  411490.0
# 508936  Centro-Oeste     GO               Faina     52  520753.0
# 508143  Centro-Oeste     GO      Cristianópolis     52  520630.0
# 476068           Sul     RS     Serafina Corrêa     43  432040.0
#
#         codRegiaoSaude        nomeRegiaoSaude       data  semanaEpi  \
# 219567         31001.0      ALFENAS / MACHADO 2020-05-27         22
# 144272         26010.0                 RECIFE 2020-05-04         19
# 22009          15013.0               MARAJO I 2020-06-27         26
# 516004         52009.0                OESTE I 2020-06-01         23
# 500079         51009.0  NORTE ARAGUAIA KARAJA 2020-05-15         20
# 325655         35064.0                    JAU 2020-04-27         18
# 396390         41016.0       16ª RS APUCARANA 2020-05-19         21
# 508936         52012.0           RIO VERMELHO 2020-06-14         25
# 508143         52002.0             CENTRO SUL 2020-05-28         22
# 476068         43017.0              REGIAO 17 2020-06-29         27
#
#        populacaoTCU2019  casosAcumulado  casosNovos  obitosAcumulado  \
# 219567            14466               1           0                0
# 144272            20524               9           1                2
# 22009             23717             139           0                1
# 516004             2913               0           0                0
# 500079             1650               0           0                0
# 325655            24403               0           0                0
# 396390             8836               1           0                0
# 508936             6627               1           0                0
# 508143             2966               0           0                0
# 476068            17502             195           4                1
#
#         obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 219567            0               NaN                    NaN
# 144272            0               NaN                    NaN
# 22009             0               NaN                    NaN
# 516004            0               NaN                    NaN
# 500079            0               NaN                    NaN
# 325655            0               NaN                    NaN
# 396390            0               NaN                    NaN
# 508936            0               NaN                    NaN
# 508143            0               NaN                    NaN
# 476068            0               NaN                    NaN
#
#         interior/metropolitana
# 219567                     0.0
# 144272                     1.0
# 22009                      0.0
# 516004                     0.0
# 500079                     0.0
# 325655                     0.0
# 396390                     0.0
# 508936                     0.0
# 508143                     0.0
# 476068                     0.0

# %%
df.describe()
# Out:
#                coduf         codmun  codRegiaoSaude      semanaEpi  \
# count  522922.000000  519338.000000   517301.000000  522922.000000
# mean       32.056045  322233.696489    32099.145697      20.129151
# std         9.775293   97433.370899     9724.179486       4.032222
# min        11.000000  110000.000000    11001.000000       9.000000
# 25%        25.000000  250940.000000    25008.000000      17.000000
# 50%        31.000000  314075.000000    31050.000000      20.000000
# 75%        41.000000  411220.000000    41011.000000      24.000000
# max        76.000000  530010.000000    53001.000000      27.000000
#
#        casosAcumulado     casosNovos  obitosAcumulado    obitosNovos  \
# count    5.229220e+05  522922.000000    522922.000000  522922.000000
# mean     2.215110e+02       8.311486        11.411239       0.347845
# std      8.347994e+03     286.775723       415.511399      11.171494
# min      0.000000e+00   -1812.000000         0.000000     -36.000000
# 25%      0.000000e+00       0.000000         0.000000       0.000000
# 50%      1.000000e+00       0.000000         0.000000       0.000000
# 75%      1.100000e+01       0.000000         0.000000       0.000000
# max      1.448753e+06   54771.000000     60632.000000    1473.000000
#
#        Recuperadosnovos  emAcompanhamentoNovos  interior/metropolitana
# count         74.000000              74.000000           517301.000000
# mean      244818.243243          245248.864865                0.072005
# std       231354.723315          183320.899296                0.258496
# min        22130.000000           14062.000000                0.000000
# 25%        56336.750000           71991.000000                0.000000
# 50%       156213.000000          202854.500000                0.000000
# 75%       375699.500000          426891.500000                0.000000
# max       826866.000000          561255.000000                1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522922 entries, 0 to 522921
# Data columns (total 17 columns):
# regiao                    522922 non-null object
# estado                    522794 non-null object
# municipio                 517301 non-null object
# coduf                     522922 non-null int64
# codmun                    519338 non-null float64
# codRegiaoSaude            517301 non-null float64
# nomeRegiaoSaude           517301 non-null object
# data                      522922 non-null datetime64[ns]
# semanaEpi                 522922 non-null int64
# populacaoTCU2019          520885 non-null object
# casosAcumulado            522922 non-null int64
# casosNovos                522922 non-null int64
# obitosAcumulado           522922 non-null int64
# obitosNovos               522922 non-null int64
# Recuperadosnovos          74 non-null float64
# emAcompanhamentoNovos     74 non-null float64
# interior/metropolitana    517301 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(5)
# memory usage: 67.8+ MB

# %%
df.shape
# Out:
# (522922, 17)

# %% [markdown]
# ### Formatando o tipo da coluna 'data'

# %%
df['data'] = df['data'].dt.strftime('%d/%m')

# %%
df.query('municipio  == "São José dos Campos"').plot(kind='bar', x='data', y ='casosAcumulado',figsize = (20,10),label='Casos confirmados')
plt.title('Número de casos confirmados acumulado em SJC')
plt.xlabel('Data')
plt.show()

# %%
df.query('municipio  == "São José dos Campos"').groupby('semanaEpi')['casosNovos'].sum().plot(kind='bar', figsize = (20,10),label='Casos confirmados', color = 'm')
plt.title('Número de casos semanais desde o primeiro caso confirmado')
plt.xlabel('Semana')
plt.show()

# %%
df.query('municipio == "São José dos Campos" and semanaEpi >= 22').plot(kind= 'bar', x = 'data', y= 'casosNovos',label = 'Número de casos confimados', figsize = (20,10))
plt.title('Novos casos nas últimas 5 semanas')
plt.ylabel('Número de novos casos diários')
plt.xlabel('Semana')
plt.show()

# %%
df.query('municipio == "São José dos Campos" and semanaEpi >= 22').plot(kind='bar', x ='data', y='obitosNovos',label = 'Número de óbitos',ax = plt.gca(), figsize = (20,10), color = 'RED')
plt.title('Novos óbitos nas últimas 5 semanas')
plt.ylabel('Número de novos óbitos diários')
plt.xlabel('Semana')
plt.show()

# %%
cidades = ['São José dos Campos', 'Jacareí', 'Caçapava', 'Taubaté']
cidades.sort()
for c in cidades:
    df[df['municipio'] == c].plot(kind='line', x = 'data', y='casosAcumulado', label = c, ax = plt.gca(), figsize = (20,10))
plt.title('Casos confirmados acumulados de SJC e os três municípios mais próximos')
plt.ylabel('Número de casos acumulados')
plt.xlabel('Data')
plt.show()

# %%
dfsp = gpd.read_file('covid19-sp.csv', encoding='UTF-8')
dfsp = dfsp.drop("geometry", axis = 1)
dfsp = dfsp.drop([627], axis = 0)
dfsp["last_available_confirmed"] = dfsp["last_available_confirmed"].astype("int")

# %%
dfsp = dfsp.merge(sp[["CD_MUN", "geometry"]], left_on="city_ibge_code", right_on="CD_MUN", how="left")

# %%
dfsp.head()
# Out:
#   epidemiological_week        date order_for_place state              city  \
# 0                   27  2020-07-01              90    SP        Adamantina
# 1                   27  2020-07-01              63    SP            Adolfo
# 2                   27  2020-07-01              70    SP             Aguaí
# 3                   27  2020-07-01              64    SP    Águas da Prata
# 4                   27  2020-07-01              91    SP  Águas de Lindóia
#
#   city_ibge_code place_type  last_available_confirmed  \
# 0        3500105       city                        58
# 1        3500204       city                        22
# 2        3500303       city                        75
# 3        3500402       city                         2
# 4        3500501       city                        42
#
#   last_available_confirmed_per_100k_inhabitants new_confirmed  \
# 0                                     165.39295             2
# 1                                     617.63054             1
# 2                                     206.58312             3
# 3                                      24.44988             0
# 4                                     224.53889             0
#
#   last_available_deaths new_deaths last_available_death_rate  \
# 0                     5          0                    0.0862
# 1                     2          0                    0.0909
# 2                     4          0                    0.0533
# 3                     1          0                       0.5
# 4                     4          0                    0.0952
#
#   estimated_population_2019 is_last is_repeated   CD_MUN  \
# 0                     35068   False       False  3500105
# 1                      3562   False       False  3500204
# 2                     36305   False       False  3500303
# 3                      8180   False       False  3500402
# 4                     18705   False       False  3500501
#
#                                             geometry
# 0  POLYGON ((-51.179193518 -21.687903693, -51.179...
# 1  POLYGON ((-49.612486032 -21.261098889, -49.612...
# 2  POLYGON ((-47.219479486 -22.039196713, -47.217...
# 3  POLYGON ((-46.730758653 -21.943536897, -46.730...
# 4  POLYGON ((-46.660565296 -22.479565612, -46.660...

# %%
ax = sp.plot(color="grey", figsize = (20,10))
dfsp.plot(ax = ax, column='last_available_confirmed',cmap = 'tab20b')
fig, ax = plt.subplots(figsize=(20, 0.5))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=129328)
cmap = mpl.cm.tab20b
cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='horizontal')

cb1.set_label('Casos confirmados no estado de SP',fontsize=17)
plt.show()

# %%
dfsp = dfsp.drop([546], axis = 0)

# %%
ax = sp.plot(color="grey", figsize = (20,10))
dfsp.plot(ax = ax, column='last_available_confirmed',cmap = 'tab20b')
fig, ax = plt.subplots(figsize=(20, 0.5))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=9448)
cmap = mpl.cm.tab20b
cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='horizontal')
cb1.set_label('Casos confirmados no estado de SP (sem a cidade de São Paulo)', fontsize=17)
plt.show()
